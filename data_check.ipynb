# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_file = "data/AB_NYC_2019.csv"
df = pd.read_csv(data_file)

# %%
df.head()
# Out:
#       id                                              name  host_id  \
# 0  44096                                  Room with a View   190409
# 1  54626                    Cozy bedroom by Yankee Stadium   190409
# 2  63588                                               LL3   295128
# 3  63610  DOMINIQUE'S NY mini efficiency* wifi*metro*quiet   310670
# 4  71812              Condo Apartment with laundry in unit   369015
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0      Waundell               Bronx    Highbridge  40.83232  -73.93184
# 1      Waundell               Bronx    Highbridge  40.83075  -73.93058
# 2  Carol Gloria               Bronx  Clason Point  40.81309  -73.85514
# 3           Vie               Bronx   Eastchester  40.88057  -73.83572
# 4          Thai               Bronx   Kingsbridge  40.87207  -73.90193
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     40               1                219    04/07/19
# 1     Private room     45               1                138    30/06/19
# 2     Private room     90               2                  0         NaN
# 3  Entire home/apt    105               2                 38    27/06/19
# 4  Entire home/apt     90              30                  4    02/01/19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               2.04                               3               353
# 1               1.45                               3               323
# 2                NaN                               7               349
# 3               0.50                              13               365
# 4               0.35                               2               346

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
df['neighbourhood'].value_counts()
# Out:
# Williamsburg                  3920
# Bedford-Stuyvesant            3714
# Harlem                        2658
# Bushwick                      2465
# Upper West Side               1971
# Hell's Kitchen                1958
# East Village                  1853
# Upper East Side               1798
# Crown Heights                 1564
# Midtown                       1545
# East Harlem                   1117
# Greenpoint                    1115
# Chelsea                       1113
# Lower East Side                911
# Astoria                        900
# Washington Heights             899
# West Village                   768
# Financial District             744
# Flatbush                       621
# Clinton Hill                   572
# Long Island City               537
# Prospect-Lefferts Gardens      535
# Park Slope                     506
# East Flatbush                  500
# Fort Greene                    489
# Murray Hill                    485
# Kips Bay                       470
# Flushing                       426
# Ridgewood                      423
# Greenwich Village              392
#                               ...
# Emerson Hill                     5
# New Brighton                     5
# Little Neck                      5
# Oakwood                          5
# Mill Basin                       4
# Castleton Corners                4
# Todt Hill                        4
# Arden Heights                    4
# Olinville                        4
# Prince's Bay                     4
# Holliswood                       4
# Spuyten Duyvil                   4
# Graniteville                     3
# Eltingville                      3
# Huguenot                         3
# Breezy Point                     3
# Neponsit                         3
# West Farms                       2
# Westerleigh                      2
# Silver Lake                      2
# Lighthouse Hill                  2
# Bay Terrace, Staten Island       2
# Howland Hook                     2
# Co-op City                       2
# Woodrow                          1
# New Dorp                         1
# Richmondtown                     1
# Fort Wadsworth                   1
# Willowbrook                      1
# Rossville                        1
# Name: neighbourhood, Length: 221, dtype: int64

# %%
df['number_of_reviews'].hist()

# %%
df['price'].hist()

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df.groupby(['neighbourhood_group'])['price'].agg(['count', 'mean', 'std'])
# Out:
#                      count        mean         std
# neighbourhood_group
# Bronx                 1091   87.496792  106.709349
# Brooklyn             20104  124.383207  186.873538
# Manhattan            21661  196.875814  291.383183
# Queens                5666   99.517649  167.102155
# Staten Island          373  114.812332  277.620403

# %%
is_Bronx = df['neighbourhood_group'] == 'Bronx'
is_Brooklyn = df['neighbourhood_group'] == 'Brooklyn'
is_Manhattan = df['neighbourhood_group'] == 'Manhattan'
is_Queens = df['neighbourhood_group'] == 'Queens'
is_StatenIsland = df['neighbourhood_group'] == 'Staten Island'

# %%
Bronx = df[is_Bronx]
Brooklyn = df[is_Brooklyn]
Manhattan = df[is_Manhattan]
Queens = df[is_Queens]
StatenIsland = df[is_StatenIsland]

# %%
Bronx.to_csv("Bronx.csv",index = False)
Brooklyn.to_csv("Brooklyn.csv",index = False)
Manhattan.to_csv("Manhattan.csv",index = False)
Queens.to_csv("Queens.csv",index = False)
StatenIsland.to_csv("StatenIsland.csv",index = False)

# %%
list(df)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
df.sort_values(by='number_of_reviews', ascending=False)
# Out:
#              id                                               name    host_id  \
# 43761   9145202                            Room near JFK Queen Bed   47621202
# 22135    903972                         Great Bedroom in Manhattan    4734398
# 22134    903947                     Beautiful Bedroom in Manhattan    4734398
# 22127    891117                       Private Bedroom in Manhattan    4734398
# 43870  10101135                            Room Near JFK Twin Beds   47621202
# 43660   8168619                  Steps away from Laguardia airport   37312959
# 22067    834190           Manhattan Lux Loft.Like.Love.Lots.Look !    2369681
# 44592  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 3269    3474320                 Private brownstone studio Brooklyn   12949460
# 1315     166172                    LG Private Room/Family Friendly     792159
# 42920    546383                   My Little Guest Room in Flushing    2680820
# 1147      26785                       Park Slope Green Guest House      42273
# 43451   6157276                    Bright LARGE BED near Manhattan   23591164
# 43880  10186192                Only Steps away from LaGuardia arpt   37312959
# 21300     58059                PRIVATE Room on Historic Sugar Hill     277379
# 42908    467634                                   yahmanscrashpads    2321321
# 21739    506121                   Cozy Room in Lively East Village    2267153
# 43557   7125107             Room steps away from LaGuardia airport   37312959
# 22201    999248                TriBeCa 2500 Sq Ft w/ Priv Elevator     273174
# 42867     63360  Safe cute near subway& Manhattan NY NY retro s...     307962
# 21712    476983                PRIVATE Room in Spacious, Quiet Apt     277379
# 44830  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 44445  15262831                 THE PRIVACY DEN ~ 5 MINUTES TO JFK   97086824
# 43376   5115372  Comfy Room Family Home LGA Airport NO CLEANING...   26432133
# 21199      5178                   Large Furnished Room Near B'way        8967
# 1157      31994                 Room with En Suite Bathroom & Deck     137814
# 43299   4550557                Bright LARGE 2 BEDS! near Manhattan   23591164
# 43606   7670562       JFK 10 & LGA 15 MINUTES A/C  PRIVATE BEDROOM   22959695
# 44702  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE   26432133
# 22163    22/06/19               5.39                               2
# ...           ...                ...                             ...
# 41730         NaN                NaN                               1
# 41731         NaN                NaN                               1
# 29011         NaN                NaN                               1
# 20030         NaN                NaN                               4
# 41734         NaN                NaN                              91
# 29015         NaN                NaN                               1
# 20023         NaN                NaN                               1
# 29019         NaN                NaN                               1
# 41739         NaN                NaN                               1
# 20046         NaN                NaN                               1
# 41719         NaN                NaN                               1
# 28994         NaN                NaN                               1
# 41708         NaN                NaN                               1
# 20069         NaN                NaN                               1
# 20068         NaN                NaN                               1
# 20066         NaN                NaN                               3
# 20063         NaN                NaN                               1
# 20061         NaN                NaN                               1
# 20060         NaN                NaN                               1
# 28989         NaN                NaN                               1
# 41709         NaN                NaN                               1
# 41717         NaN                NaN                               1
# 41710         NaN                NaN                               1
# 20056         NaN                NaN                               1
# 20055         NaN                NaN                               6
# 28990         NaN                NaN                               1
# 20053         NaN                NaN                               6
# 20052         NaN                NaN                               1
# 28993         NaN                NaN                               1
# 35125         NaN                NaN                               1
#
#        availability_365
# 43761               333
# 22135               293
# 22134               342
# 22127               339
# 43870               173
# 43660               163
# 22067               179
# 44592               341
# 3269                269
# 1315                  0
# 42920               332
# 1147                192
# 43451               331
# 43880               175
# 21300               258
# 42908               353
# 21739                13
# 43557               166
# 22201               207
# 42867               226
# 21712               238
# 44830               337
# 44445               102
# 43376               347
# 21199               220
# 1157                275
# 43299               312
# 43606                 0
# 44702               338
# 22163               231
# ...                 ...
# 41730                87
# 41731               280
# 29011                 0
# 20030               264
# 41734               245
# 29015                 0
# 20023               317
# 29019                 0
# 41739               124
# 20046               114
# 41719                54
# 28994                 0
# 41708                42
# 20069                40
# 20068                31
# 20066               213
# 20063               136
# 20061                 5
# 20060                 5
# 28989                 0
# 41709                21
# 41717                 0
# 41710                18
# 20056                53
# 20055               343
# 28990                 0
# 20053               321
# 20052                 0
# 28993                 0
# 35125                 0
#
# [48895 rows x 16 columns]

# %%
d = df.groupby(['neighbourhood_group', 'room_type'])['name'].count().reset_index()#.to_json("room_data.json", orient='records')

# %%
d
# Out:
#    neighbourhood_group        room_type   name
# 0                Bronx  Entire home/apt    379
# 1                Bronx     Private room    652
# 2                Bronx      Shared room     59
# 3             Brooklyn  Entire home/apt   9558
# 4             Brooklyn     Private room  10127
# 5             Brooklyn      Shared room    413
# 6            Manhattan  Entire home/apt  13193
# 7            Manhattan     Private room   7979
# 8            Manhattan      Shared room    480
# 9               Queens  Entire home/apt   2096
# 10              Queens     Private room   3372
# 11              Queens      Shared room    198
# 12       Staten Island  Entire home/apt    176
# 13       Staten Island     Private room    188
# 14       Staten Island      Shared room      9

# %%
d_sum = d.groupby(['room_type']).sum().reset_index()
d_sum['neighbourhood_group'] = ['all'] * len(d_sum)
d_sum
# Out:
#          room_type   name neighbourhood_group
# 0  Entire home/apt  25402                 all
# 1     Private room  22318                 all
# 2      Shared room   1159                 all

# %%
pd.concat([d, d_sum]).to_json("room_data.json", orient='records')
# Out:
# /Users/telly/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
# !open .
